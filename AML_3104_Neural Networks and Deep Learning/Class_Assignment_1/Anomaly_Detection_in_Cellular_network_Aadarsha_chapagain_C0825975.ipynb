# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Neural_Network/train.csv',encoding='windows-1252')
df.head()
# Out:
#     Time CellName  PRBUsageUL  PRBUsageDL  meanThr_DL  meanThr_UL  maxThr_DL  \
# 0  10:45    3BLTE      11.642       1.393       0.370       0.041     15.655
# 1   9:45    1BLTE      21.791       1.891       0.537       0.268     10.273
# 2   7:45    9BLTE       0.498       0.398       0.015       0.010      0.262
# 3   2:45    4ALTE       1.891       1.095       0.940       0.024     60.715
# 4   3:30   10BLTE       0.303       0.404       0.016       0.013      0.348
#
#    maxThr_UL  meanUE_DL  meanUE_UL  maxUE_DL  maxUE_UL maxUE_UL+DL  Unusual
# 0      0.644      1.114      1.025       4.0       3.0           7        1
# 1      1.154      1.353      1.085       6.0       4.0          10        1
# 2      0.164      0.995      0.995       1.0       1.0           2        1
# 3      0.825      1.035      0.995       2.0       2.0           4        1
# 4      0.168      1.011      1.011       2.0       1.0           3        0

# %%
df.describe()
# Out:
#          PRBUsageUL    PRBUsageDL    meanThr_DL    meanThr_UL     maxThr_DL  \
# count  36904.000000  36904.000000  36904.000000  36904.000000  36904.000000
# mean       7.835090      2.106396      0.560525      0.067610     17.764369
# std        8.428206      2.247514      0.727623      0.186555     15.739932
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.213000      0.707000      0.140000      0.021000      5.710750
# 50%        4.547000      1.314000      0.352000      0.040000     14.170000
# 75%       12.126000      2.728000      0.718000      0.075000     25.059500
# max       51.333000     77.505000     19.601000     12.461000    140.008000
#
#           maxThr_UL     meanUE_DL     meanUE_UL      maxUE_DL      maxUE_UL  \
# count  36904.000000  36904.000000  36904.000000  36815.000000  36815.000000
# mean       1.791974      1.173441      0.665143      4.190819      3.063371
# std        5.028928      0.214065      0.535493      1.772484      1.387446
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.362000      1.041000      0.010000      3.000000      2.000000
# 50%        0.703000      1.112000      1.011000      4.000000      3.000000
# 75%        1.242000      1.263000      1.051000      5.000000      4.000000
# max       48.253000      2.915000      2.668000     12.000000     12.000000
#
#             Unusual
# count  36904.000000
# mean       0.275932
# std        0.446989
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_36ce3_row0_col0, #T_36ce3_row1_col1, #T_36ce3_row2_col2, #T_36ce3_row3_col3, #T_36ce3_row4_col4, #T_36ce3_row5_col5, #T_36ce3_row6_col6, #T_36ce3_row7_col7, #T_36ce3_row8_col8, #T_36ce3_row9_col9, #T_36ce3_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_36ce3_row0_col1, #T_36ce3_row0_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_36ce3_row0_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_36ce3_row0_col3, #T_36ce3_row3_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_36ce3_row0_col5, #T_36ce3_row1_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_36ce3_row0_col6 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_36ce3_row0_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_36ce3_row0_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_36ce3_row0_col9, #T_36ce3_row9_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_36ce3_row0_col10, #T_36ce3_row10_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_36ce3_row1_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_36ce3_row1_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_36ce3_row1_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_36ce3_row1_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_36ce3_row1_col6 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_36ce3_row1_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_36ce3_row1_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_36ce3_row1_col9 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_36ce3_row1_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_36ce3_row2_col0, #T_36ce3_row8_col4, #T_36ce3_row9_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_36ce3_row2_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_36ce3_row2_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_36ce3_row2_col4, #T_36ce3_row4_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_36ce3_row2_col5, #T_36ce3_row6_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_36ce3_row2_col6, #T_36ce3_row2_col8, #T_36ce3_row2_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_36ce3_row2_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_36ce3_row2_col10, #T_36ce3_row4_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_36ce3_row3_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_36ce3_row3_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_36ce3_row3_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_36ce3_row3_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_36ce3_row3_col6, #T_36ce3_row7_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_36ce3_row3_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_36ce3_row3_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_36ce3_row3_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_36ce3_row3_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_36ce3_row4_col0, #T_36ce3_row5_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_36ce3_row4_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_36ce3_row4_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_36ce3_row4_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_36ce3_row4_col6, #T_36ce3_row9_col4 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_36ce3_row4_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_36ce3_row4_col8 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_36ce3_row4_col9 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_36ce3_row5_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_36ce3_row5_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_36ce3_row5_col3, #T_36ce3_row7_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_36ce3_row5_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_36ce3_row5_col6, #T_36ce3_row9_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_36ce3_row5_col7, #T_36ce3_row6_col10, #T_36ce3_row7_col5, #T_36ce3_row10_col0, #T_36ce3_row10_col1, #T_36ce3_row10_col2, #T_36ce3_row10_col3, #T_36ce3_row10_col4, #T_36ce3_row10_col6, #T_36ce3_row10_col8, #T_36ce3_row10_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_36ce3_row5_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_36ce3_row5_col9, #T_36ce3_row8_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_36ce3_row5_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_36ce3_row6_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_36ce3_row6_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_36ce3_row6_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_36ce3_row6_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_36ce3_row6_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_36ce3_row6_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_36ce3_row6_col8 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_36ce3_row6_col9 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_36ce3_row7_col0 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_36ce3_row7_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_36ce3_row7_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_36ce3_row7_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_36ce3_row7_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_36ce3_row7_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_36ce3_row7_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_36ce3_row8_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_36ce3_row8_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_36ce3_row8_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_36ce3_row8_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_36ce3_row8_col6 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_36ce3_row8_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_36ce3_row8_col9, #T_36ce3_row9_col8 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_36ce3_row8_col10 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_36ce3_row9_col1 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_36ce3_row9_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_36ce3_row9_col6 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_36ce3_row9_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_36ce3_row9_col10 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_36ce3_row10_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36ce3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PRBUsageUL</th>
#       <th class="col_heading level0 col1" >PRBUsageDL</th>
#       <th class="col_heading level0 col2" >meanThr_DL</th>
#       <th class="col_heading level0 col3" >meanThr_UL</th>
#       <th class="col_heading level0 col4" >maxThr_DL</th>
#       <th class="col_heading level0 col5" >maxThr_UL</th>
#       <th class="col_heading level0 col6" >meanUE_DL</th>
#       <th class="col_heading level0 col7" >meanUE_UL</th>
#       <th class="col_heading level0 col8" >maxUE_DL</th>
#       <th class="col_heading level0 col9" >maxUE_UL</th>
#       <th class="col_heading level0 col10" >Unusual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36ce3_level0_row0" class="row_heading level0 row0" >PRBUsageUL</th>
#       <td id="T_36ce3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_36ce3_row0_col1" class="data row0 col1" >0.449178</td>
#       <td id="T_36ce3_row0_col2" class="data row0 col2" >0.482782</td>
#       <td id="T_36ce3_row0_col3" class="data row0 col3" >0.286596</td>
#       <td id="T_36ce3_row0_col4" class="data row0 col4" >0.461718</td>
#       <td id="T_36ce3_row0_col5" class="data row0 col5" >0.217282</td>
#       <td id="T_36ce3_row0_col6" class="data row0 col6" >0.659076</td>
#       <td id="T_36ce3_row0_col7" class="data row0 col7" >0.548

# %%
df = df.drop(['maxUE_DL','maxUE_UL','maxUE_UL+DL'],axis=1)

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_435f0_row0_col0, #T_435f0_row1_col1, #T_435f0_row2_col2, #T_435f0_row3_col3, #T_435f0_row4_col4, #T_435f0_row5_col5, #T_435f0_row6_col6, #T_435f0_row7_col7, #T_435f0_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_435f0_row0_col1, #T_435f0_row0_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_435f0_row0_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_435f0_row0_col3, #T_435f0_row3_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_435f0_row0_col5, #T_435f0_row1_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_435f0_row0_col6 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_435f0_row0_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_435f0_row0_col8, #T_435f0_row8_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_435f0_row1_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_435f0_row1_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_435f0_row1_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_435f0_row1_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_435f0_row1_col6 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_435f0_row1_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_435f0_row1_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_435f0_row2_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_435f0_row2_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_435f0_row2_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_435f0_row2_col4, #T_435f0_row4_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_435f0_row2_col5, #T_435f0_row6_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_435f0_row2_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_435f0_row2_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_435f0_row2_col8, #T_435f0_row4_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_435f0_row3_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_435f0_row3_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_435f0_row3_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_435f0_row3_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_435f0_row3_col6, #T_435f0_row7_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_435f0_row3_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_435f0_row3_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_435f0_row4_col0, #T_435f0_row5_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_435f0_row4_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_435f0_row4_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_435f0_row4_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_435f0_row4_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_435f0_row4_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_435f0_row5_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_435f0_row5_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_435f0_row5_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_435f0_row5_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_435f0_row5_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_435f0_row5_col7, #T_435f0_row6_col8, #T_435f0_row7_col5, #T_435f0_row8_col0, #T_435f0_row8_col1, #T_435f0_row8_col2, #T_435f0_row8_col3, #T_435f0_row8_col4, #T_435f0_row8_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_435f0_row5_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_435f0_row6_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_435f0_row6_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_435f0_row6_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_435f0_row6_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_435f0_row6_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_435f0_row6_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_435f0_row7_col0 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_435f0_row7_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_435f0_row7_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_435f0_row7_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_435f0_row7_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_435f0_row7_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_435f0_row8_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_435f0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PRBUsageUL</th>
#       <th class="col_heading level0 col1" >PRBUsageDL</th>
#       <th class="col_heading level0 col2" >meanThr_DL</th>
#       <th class="col_heading level0 col3" >meanThr_UL</th>
#       <th class="col_heading level0 col4" >maxThr_DL</th>
#       <th class="col_heading level0 col5" >maxThr_UL</th>
#       <th class="col_heading level0 col6" >meanUE_DL</th>
#       <th class="col_heading level0 col7" >meanUE_UL</th>
#       <th class="col_heading level0 col8" >Unusual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_435f0_level0_row0" class="row_heading level0 row0" >PRBUsageUL</th>
#       <td id="T_435f0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_435f0_row0_col1" class="data row0 col1" >0.449178</td>
#       <td id="T_435f0_row0_col2" class="data row0 col2" >0.482782</td>
#       <td id="T_435f0_row0_col3" class="data row0 col3" >0.286596</td>
#       <td id="T_435f0_row0_col4" class="data row0 col4" >0.461718</td>
#       <td id="T_435f0_row0_col5" class="data row0 col5" >0.217282</td>
#       <td id="T_435f0_row0_col6" class="data row0 col6" >0.659076</td>
#       <td id="T_435f0_row0_col7" class="data row0 col7" >0.548276</td>
#       <td id="T_435f0_row0_col8" class="data row0 col8" >-0.117299</td>
#     </tr>
#     <tr>
#       <th id="T_435f0_level0_row1" class="row_heading level0 row1" >PRBUsageDL</th>
#       <td id="T_435f0_row1_col0" class="data row1 col0" >0.449178</td>
#       <td id="T_435f0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_435f0_row1_col2" class="data row1 col2" >0.793071</td>
#       <td id="T_435f0_row1_col3" class="data row1 col3" >0.250486</td>
#       <td id="T_435f0_row1_col4" class="data row1 col4" >0.452983</td>
#       <td id="T_435f0_row1_col5" class="data row1 col5" >0.298500</td>
#       <td id="T_435f0_row1_col6" class="data row1 col6" >0.607479</td>
#       <td id="T_435f0_row1_col7" class="data row1 col7" >0.002317</td>
#       <td id="T_435f0_row1_col8" class="data row1 col8" >-0.090100</td>
#     </tr>
#     <tr>
#       <th id="T_435f0_level0_row2" class="row_heading level0 row2" >meanThr_DL</th>
#       <td id="T_435f0_row2_col0" class="data row2 col0" >0.482782</td>
#       <td id="T_435f0_row2_col1" class="data row2 col1" >0.793071</td>
#       <td id="T_435f0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_435f0_row2_col3" class="data row2 col3" >0.299374</td>
#       <td id="T_435f0_row2_col4" class="data row2 col4" >0.629836</td>
#       <td id="T_435f0_row2_col5" class="data row2 col5" >0.486367</td>
#       <td id="T_435f0_row2_col6" class="data row2 col6" >0.488197</td>
#       <td id="T_435f0_row2_col7" class="data row2 col7" >0.086440</td>
#       <td id="T_435f0_row2_col8" class="data row2 col8" >-0.065517</td>
#     </tr>
#     <tr>
#       <th id="T_435f0_level0_row3" class="row_heading level0 row3" >meanThr_UL</th>
#       <td id="T_435f0_row3_col0" class="data row3 col0" >0.286596</td>
#       <td id="T_435f0_row3_col1" class="data row3 col1" >0.250486</td>
#       <td id="T_435f0_row3_col2" class="data row3 col2" >0.299374</td>
#       <td id="T_435f0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_435f0_row3_col4" class="data row3 col4" >0.199296</td>
#       <td id="T_435f0_row3_col5" class="data row3 col5" >0.409001</td>
#       <td id="T_435f0_row3_col6" class="data row3 col6" >0.233858</td>
#       <td id="T_435f0_row3_col7" class="data row3 col7" >0.026614</td>

# %%
df['Unusual'].plot(kind='kde')

# %%
print("Value Count:\n",df["Unusual"].value_counts())
#  try in percentage as well
df.Unusual.value_counts(normalize=True)
# Out:
# Value Count:
#  0    26721
# 1    10183
# Name: Unusual, dtype: int64
# 0    0.724068
# 1    0.275932
# Name: Unusual, dtype: float64

# %%
df.isnull().sum()
# Out:
# Time          0
# CellName      0
# PRBUsageUL    0
# PRBUsageDL    0
# meanThr_DL    0
# meanThr_UL    0
# maxThr_DL     0
# maxThr_UL     0
# meanUE_DL     0
# meanUE_UL     0
# Unusual       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Time          0
# CellName      0
# PRBUsageUL    0
# PRBUsageDL    0
# meanThr_DL    0
# meanThr_UL    0
# maxThr_DL     0
# maxThr_UL     0
# meanUE_DL     0
# meanUE_UL     0
# Unusual       0
# dtype: int64

# %%
# You can typecast to int using astype(int) and divide it by 10**9 to get the number of seconds to the unix epoch start.
df['Time'] = pd.to_datetime(df['Time']).astype(int)/ 10**9
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
# split cellName to digits and String
result = df['CellName'].str.split('(\d+)([A-Za-z]+)', expand=True)
df['Cell_power'] = result[1]
# get the first alphabet of string as category[A, B, C, U, V, W] 
df['Cell_category']= result[2].astype(str).str[0]
# one hot encoding for category
df = pd.concat([df,pd.get_dummies(df['Cell_category'])],axis=1)
# Cell name features have been used already drop redundant column
df =df.drop(['Cell_category','CellName'],axis=1)

# %%
df.dtypes
# Out:
# Time          float64
# PRBUsageUL    float64
# PRBUsageDL    float64
# meanThr_DL    float64
# meanThr_UL    float64
# maxThr_DL     float64
# maxThr_UL     float64
# meanUE_DL     float64
# meanUE_UL     float64
# Unusual         int64
# Cell_power     object
# A               uint8
# B               uint8
# C               uint8
# U               uint8
# V               uint8
# W               uint8
# dtype: object

# %%
df['Cell_power'] = df['Cell_power'].astype('int')

# %%
df.dtypes
# Out:
# Time           float64
# PRBUsageUL     float64
# PRBUsageDL     float64
# meanThr_DL     float64
# meanThr_UL     float64
# maxThr_DL      float64
# maxThr_UL      float64
# meanUE_DL      float64
# meanUE_UL      float64
# maxUE_DL       float64
# maxUE_UL       float64
# maxUE_UL+DL      int64
# Unusual          int64
# Cell_power       int64
# A                uint8
# B                uint8
# C                uint8
# U                uint8
# V                uint8
# W                uint8
# dtype: object

# %%
X_train=df.loc[:, df.columns != 'Unusual']
Y_train= df['Unusual'].astype('int')

# %%
# When normalizing we simply subtract the mean and divide by standard deviation.
X_train = X_train.apply(lambda iterator: ((iterator - iterator.mean())/iterator.std()).round(2))

# %%
X_train.head()
# Out:
#    Time  PRBUsageUL  PRBUsageDL  meanThr_DL  meanThr_UL  maxThr_DL  maxThr_UL  \
# 0 -0.14        0.45       -0.32       -0.26       -0.14      -0.13      -0.23
# 1 -0.28        1.66       -0.10       -0.03        1.07      -0.48      -0.13
# 2 -0.57       -0.87       -0.76       -0.75       -0.31      -1.11      -0.32
# 3 -1.30       -0.71       -0.45        0.52       -0.23       2.73      -0.19
# 4 -1.19       -0.89       -0.76       -0.75       -0.29      -1.11      -0.32
#
#    meanUE_DL  meanUE_UL  Cell_power     A     B     C     U     V     W
# 0      -0.28       0.67       -1.09 -0.66  1.63 -0.57 -0.25 -0.25 -0.25
# 1       0.84       0.78       -1.87 -0.66  1.63 -0.57 -0.25 -0.25 -0.25
# 2      -0.83       0.62        1.26 -0.66  1.63 -0.57 -0.25 -0.25 -0.25
# 3      -0.65       0.62       -0.70  1.51 -0.61 -0.57 -0.25 -0.25 -0.25
# 4      -0.76       0.65        1.65 -0.66  1.63 -0.57 -0.25 -0.25 -0.25

# %%
Y_train.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Unusual, dtype: int64

# %%
X_train
# Out:
#        Time  PRBUsageUL  PRBUsageDL  meanThr_DL  meanThr_UL  maxThr_DL  \
# 0     -0.14        0.45       -0.32       -0.26       -0.14      -0.13
# 1     -0.28        1.66       -0.10       -0.03        1.07      -0.48
# 2     -0.57       -0.87       -0.76       -0.75       -0.31      -1.11
# 3     -1.30       -0.71       -0.45        0.52       -0.23       2.73
# 4     -1.19       -0.89       -0.76       -0.75       -0.29      -1.11
# ...     ...         ...         ...         ...         ...        ...
# 36899  1.42       -0.03       -0.58       -0.54       -0.16      -0.62
# 36900 -0.28        0.15       -0.40       -0.51       -0.20       0.11
# 36901  0.26       -0.41       -0.54       -0.30       -0.20      -0.36
# 36902  0.11        0.65        0.28       -0.00       -0.01       0.66
# 36903  0.59        1.71        0.23        0.35        0.04       4.01
#
#        maxThr_UL  meanUE_DL  meanUE_UL  Cell_power     A     B     C     U  \
# 0          -0.23      -0.28       0.67       -1.09 -0.66  1.63 -0.57 -0.25
# 1          -0.13       0.84       0.78       -1.87 -0.66  1.63 -0.57 -0.25
# 2          -0.32      -0.83       0.62        1.26 -0.66  1.63 -0.57 -0.25
# 3          -0.19      -0.65       0.62       -0.70  1.51 -0.61 -0.57 -0.25
# 4          -0.32      -0.76       0.65        1.65 -0.66  1.63 -0.57 -0.25
# ...          ...        ...        ...         ...   ...   ...   ...   ...
# 36899      -0.28      -0.34      -1.22        0.09  1.51 -0.61 -0.57 -0.25
# 36900      -0.04      -0.24       0.68        0.87 -0.66 -0.61  1.76 -0.25
# 36901      -0.25      -0.51       0.63        1.26 -0.66  1.63 -0.57 -0.25
# 36902      -0.18       0.23       0.74       -1.09 -0.66 -0.61  1.76 -0.25
# 36903      -0.19       0.70       0.89       -0.30 -0.66  1.63 -0.57 -0.25
#
#           V     W
# 0     -0.25 -0.25
# 1     -0.25 -0.25
# 2     -0.25 -0.25
# 3     -0.25 -0.25
# 4     -0.25 -0.25
# ...     ...   ...
# 36899 -0.25 -0.25
# 36900 -0.25 -0.25
# 36901 -0.25 -0.25
# 36902 -0.25 -0.25
# 36903 -0.25 -0.25
#
# [36904 rows x 16 columns]

# %%
Y_train
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 36899    0
# 36900    0
# 36901    1
# 36902    0
# 36903    0
# Name: Unusual, Length: 36904, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()

# %%
# train the model
regressor.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import f1_score

y_pred = regressor.predict(X_train)
classification_report_= classification_report(Y_train, y_pred)
print("classification_report_\n",classification_report_)
print('\n f1score: ',f1_score(Y_train, y_pred, zero_division=1))
print('\n Accuracy: ', accuracy_score(Y_train, y_pred))
# Out:
# classification_report_
#                precision    recall  f1-score   support
#
#            0       0.72      0.99      0.84     26721
#            1       0.20      0.01      0.01     10183
#
#     accuracy                           0.72     36904
#    macro avg       0.46      0.50      0.42     36904
# weighted avg       0.58      0.72      0.61     36904
#
#
#  f1score:  0.010702341137123745
#
#  Accuracy:  0.7194613050075872

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_train, y_pred)
# Out:
# array([[26495,   226],
#        [10127,    56]])

# %%
from sklearn.decomposition import PCA

pca_celltower = PCA(n_components=2)
principalComponents_celltower = pca_celltower.fit_transform(X_train)

# %%
principal_celltower_Df = pd.DataFrame(data = principalComponents_celltower
             , columns = ['PCA1', 'PCA2'])

# %%
principal_celltower_Df.tail()
# Out:
#            PCA1      PCA2
# 36899 -0.995766  0.091963
# 36900 -0.506805 -0.924813
# 36901 -0.711191 -0.406539
# 36902  0.913855 -1.225102
# 36903  3.175204 -0.927429

# %%
print('Explained variation per principal component: {}'.format(pca_celltower.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.23872307 0.12398461]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
plt.title("Principal Component Analysis of Cell Tower Dataset",fontsize=20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = df['Unusual'] == target
    plt.scatter(principal_celltower_Df.loc[indicesToKeep, 'PCA1']
               , principal_celltower_Df.loc[indicesToKeep, 'PCA2'], c = color, s = 50)
plt.legend(targets,prop={'size': 15})
